# %% [markdown]
# *   In theory we could create a Figure object and then manually add and arrange sets of axes to line up multiple plots side by side.
# *   However, Matplotlib comes with a pre-configured function call **plt.subplots()** that automatically does this for us!

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# * The plt.subplots() call allows us to easily create Figure and Axes objects in side by side formations.
# * The plt.subplots() command returns a tuple containing the Figure canvas and then a numpy array holding the axes objects.

# %% [markdown]
# * plt.subplots() returns a tuple which by common convention we label**(fig,axes):**
# * **fig**
# This is the entire Figure canvas.
# * **axes**
# This is a numpy array holding each of the axes according to position in the overall canvas.

# %%
a = np.linspace(0,10,11) # 0 ile 10 arasında eşit aralıklı 11 sayı oluştur.
b = a ** 4

# %%
x = np.arange(0,10)
y = 2 * x

# %% [markdown]
# # plt.subplots()
#
# The plt.subplots() object will act as a more automatic axis manager. This makes it much easier to show multiple plots side by side.

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title'); #; hides Out[]

# %% [markdown]
# ## Adding rows and columns
#
# Then you can specify the number of rows and columns when creating the subplots() object:

# %%
# # Empty canvas of 1 by 2 subplots
fig,axes = plt.subplots(nrows=1, ncols=2)
#the minute you start asking for more than one column, axes is no longer a Matplotlib axes object.

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes.shape #one dimensional
# Out:
# (2,)

# %%
axes #because there's essentially just two axes.
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y)
axes[1].plot(a,b)

# %%
fig,axes = plt.subplots(nrows=2, ncols=2)
axes[0].plot(x,y)
axes[1].plot(a,b)

#this numpy array of axes is actually 2 dimensional
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1580122169.py in <cell line: 0>()
#       1 fig,axes = plt.subplots(nrows=2, ncols=2)
# ----> 2 axes[0].plot(x,y)
#       3 axes[1].plot(a,b)
#       4
#       5 #this numpy array of axes is actually 2 dimensional
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes.shape
# Out:
# (2, 2)

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
fig,axes = plt.subplots(nrows=2, ncols=2)
axes[0][0].plot(x,y)
axes[1][1].plot(a,b)

# %% [markdown]
# A common issue with matplolib is overlapping subplots or figures. We ca use **fig.tight_layout()** or **plt.tight_layout()** method, which automatically adjusts the positions of the axes on the figure canvas so that there is no overlapping content:

# %%
fig,axes = plt.subplots(nrows=3, ncols=1)

for ax in axes:
  ax.plot(x,y)

plt.tight_layout()

# %% [markdown]
# ### Manual spacing on subplots()
#
# Use .subplots_adjust to adjust spacing manually.
#
# Full Details Here: https://matplotlib.org/3.2.2/api/_as_gen/matplotlib.pyplot.subplots_adjust.html
#
# Example from link:
#
# * left = 0.125  # the left side of the subplots of the figure
# * right = 0.9   # the right side of the subplots of the figure
# * bottom = 0.1  # the bottom of the subplots of the figure
# * top = 0.9     # the top of the subplots of the figure
# * wspace = 0.2  # the amount of width reserved for space between subplots,
#               # expressed as a fraction of the average axis width
# * hspace = 0.2  # the amount of height reserved for space between subplots,
#               # expressed as a fraction of the average axis height

# %%
fig,axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x,y)
axes[0][1].plot(x,y)

axes[1][0].plot(x,y)
axes[1][0].set_ylabel("Y label 1,0")
axes[1][0].set_xlim(2,6)

axes[1][1].plot(a,b)
axes[1][1].set_title("Title 1,1")

fig.suptitle("Figure Level",fontsize=16)

fig.subplots_adjust(wspace=1,hspace=0.5)

# to save the plot
fig.savefig("new_subplots.png",bbox_inches="tight")
